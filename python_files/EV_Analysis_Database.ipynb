# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Set up Splinter
browser = Browser('chrome')

# %%
# Visit EV Vehicles database site
url = 'https://ev-database.org/uk/compare/newest-upcoming-electric-vehicle#sort:path~type~order=.id~number~desc|range-slider-range:prev~next=0~600|range-slider-towweight:prev~next=0~2500|range-slider-acceleration:prev~next=2~23|range-slider-fastcharge:prev~next=0~1100|range-slider-eff:prev~next=150~500|range-slider-topspeed:prev~next=60~260|paging:currentPage=0|paging:number=all'
browser.visit(url)

# %%
# Parse the website
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Find the table
table = soup.find('div', class_='list')
table
# Out:
# <div class="list">
# <div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/2033/Volkswagen-ID5-GTX"><img alt="Volkswagen ID.5 GTX" data-src="/img/auto/Volkswagen_ID5_GTX_2023/Volkswagen_ID5_GTX_2023-01-thumb.jpg" data-src-retina="/img/auto/Volkswagen_ID5_GTX_2023/Volkswagen_ID5_GTX_2023-01-thumb@2x.jpg" src="/img/auto/Volkswagen_ID5_GTX_2023/Volkswagen_ID5_GTX_2023-01-thumb@2x.jpg"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/2033/Volkswagen-ID5-GTX"><span class="volkswagen">Volkswagen</span> <span class="model">ID.5 GTX</span></a></h2><span class="date_from hidden">1698793200</span><span class="date_to hidden"></span><span class="rank hidden">11</span><span class="id hidden">2033</span> <span class="not-current">(coming soon)</span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">770</span>
#           77 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">215</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£19 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from November 2023</span>
# </div>
# </div>
# <div class="icons">
# <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1200</span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="awd fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">5.5 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">112 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">265 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">291 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">390 mph</span>
# <span class="fastcharge_speed hidden">390</span>
# </p>
# <span class="range hidden">265 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter50-75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£57,000 *</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£750</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/2031/Volkswagen-ID5-Pro"><img alt="Volkswagen ID.5 Pro" data-src="/img/auto/Volkswagen_ID5/Volkswagen_ID5-01-thumb.jpg" data-src-retina="/img/auto/Volkswagen_ID5/Volkswagen_ID5-01-thumb@2x.jpg" src="/img/auto/Volkswagen_ID5/Volkswagen_ID5-01-thumb@2x.jpg"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/2031/Volkswagen-ID5-Pro"><span class="volkswagen">Volkswagen</span> <span class="model">ID.5 Pro</span></a></h2><span class="date_from hidden">1698793200</span><span class="date_to hidden"></span><span class="rank hidden">11</span><span class="id hidden">2031</span> <span class="not-current">(coming soon)</span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">770</span>
#           77 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">182</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£17 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from November 2023</span>
# </div>
# </div>
# <div class="icons">
# <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1000</span><span title="Rear Wheel Drive"><span class="achter far fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="achter fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">6.7 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">112 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">285 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">270 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">420 mph</span>
# <span class="fastcharge_speed hidden">420</span>
# </p>
# <span class="range hidden">285 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter50-75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£52,000 *</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£700</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/2030/Volkswagen-ID4-GTX"><img alt="Volkswagen ID.4 GTX" data-src="/img/auto/Volkswagen_ID4_GTX_2023/Volkswagen_ID4_GTX_2023-01-thumb.jpg" data-src-retina="/img/auto/Volkswagen_ID4_GTX_2023/Volkswagen_ID4_GTX_2023-01-thumb@2x.jpg" src="/img/auto/Volkswagen_ID4_GTX_2023/Volkswagen_ID4_GTX_2023-01-thumb@2x.jpg"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/2030/Volkswagen-ID4-GTX"><span class="volkswagen">Volkswagen</span> <span class="model">ID.4 GTX</span></a></h2><span class="date_from hidden">1698793200</span><span class="date_to hidden"></span><span class="rank hidden">4</span><span class="id hidden">2030</span> <span class="not-current">(coming soon)</span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">770</span>
#           77 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">204</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£18 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from November 2023</span>
# </div>
# </div>
# <div class="icons">
# <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1200</span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="awd fas fa-circle"></span></span><span class="roofrack hidden" title="Roofbox possible">Roofbox possible</span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">5.4 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">112 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">260 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">296 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">390 mph</span>
# <span class="fastcharge_speed hidden">390</span>
# </p>
# <span class="range hidden">260 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter50-75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£53,000 *</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£700</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/2028/Volkswagen-ID4-Pro"><img alt="Volkswagen ID.4 Pro" data-src="/img/auto/Volkswagen_ID4/Volkswagen_ID4-01-thumb.jpg" data-src-retina="/img/auto/Volkswagen_ID4/Volkswagen_ID4-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/2028/Volkswagen-ID4-Pro"><span class="volkswagen">Volkswagen</span> <span class="model">ID.4 Pro</span></a></h2><span class="date_from hidden">1698793200</span><span class="date_to hidden"></span><span class="rank hidden">28</span><span class="id hidden">2028</span> <span class="not-current">(coming soon)</span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">770</span>
#           77 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">167</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£15 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from November 2023</span>
# </div>
# </div>
# <div class="icons">
# <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1000</span><span title="Rear Wheel Drive"><span class="achter far fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="achter fas fa-circle"></span></span><span class="roofrack hidden" title="Roofbox possible">Roofbox possible</span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">6.7 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">112 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">270 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">285 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">400 mph</span>
# <span class="fastcharge_speed hidden">400</span>
# </p>
# <span class="range hidden">270 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter40-50" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£45,000 *</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£600</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/2027/Volkswagen-ID4-Pure"><img alt="Volkswagen ID.4 Pure" data-src="/img/auto/Volkswagen_ID4/Volkswagen_ID4-01-thumb.jpg" data-src-retina="/img/auto/Volkswagen_ID4/Volkswagen_ID4-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/2027/Volkswagen-ID4-Pure"><span class="volkswagen">Volkswagen</span> <span class="model">ID.4 Pure</span></a></h2><span class="date_from hidden">1698793200</span><span class="date_to hidden"></span><span class="rank hidden">11</span><span class="id hidden">2027</span> <span class="not-current">(coming soon)</span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">520</span>
#           52 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">223</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£13 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from November 2023</span>
# </div>
# </div>
# <div class="icons">
# <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1000</span><span title="Rear Wheel Drive"><span class="achter far fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="achter fas fa-circle"></span></span><span class="roofrack hidden" title="Roofbox possible">Roofbox possible</span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">9.0 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">99 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">175 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">297 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">220 mph</span>
# <span class="fastcharge_speed hidden">220</span>
# </p>
# <span class="range hidden">175 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter30-40" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£39,000 *</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£525</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/2012/Mercedes-EQS-AMG-53-4MATICplus"><img alt="Mercedes EQS AMG 53 4MATIC+" data-src="/img/auto/Mercedes_EQS_AMG_2021/Mercedes_EQS_AMG_2021-01-thumb.jpg" data-src-retina="/img/auto/Mercedes_EQS_AMG_2021/Mercedes_EQS_AMG_2021-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/2012/Mercedes-EQS-AMG-53-4MATICplus"><span class="mercedes">Mercedes</span> <span class="model">EQS AMG 53 4MATIC+</span></a></h2><span class="date_from hidden">1685570400</span><span class="date_to hidden"></span><span class="rank hidden">90</span><span class="id hidden">2012</span><span class="current"></span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">1084</span>
#           108.4 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">483</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£54 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since June 2023</span>
# </div>
# </div>
# <div class="icons">
# <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">750</span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="awd fas fa-circle"></span></span><span class="roofrack hidden" title="Roofbox possible">Roofbox possible</span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-sedan hidden">Sedan</span><span class="size-f hidden">F</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">3.4 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">155 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">335 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">324 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">500 mph</span>
# <span class="fastcharge_speed hidden">500</span>
# </p>
# <span class="range hidden">335 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£161,860</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£1,696</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/2008/Mercedes-EQS-450plus"><img alt="Mercedes EQS 450+" data-src="/img/auto/Mercedes_EQS_2021/Mercedes_EQS_2021-01-thumb.jpg" data-src-retina="/img/auto/Mercedes_EQS_2021/Mercedes_EQS_2021-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/2008/Mercedes-EQS-450plus"><span class="mercedes">Mercedes</span> <span class="model">EQS 450+</span></a></h2><span class="date_from hidden">1685570400</span><span class="date_to hidden"></span><span class="rank hidden">214</span><span class="id hidden">2008</span><span class="current"></span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">1084</span>
#           108.4 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">267</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£35 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since June 2023</span>
# </div>
# </div>
# <div class="icons">
# <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">750</span><span title="Rear Wheel Drive"><span class="achter far fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="achter fas fa-circle"></span></span><span class="roofrack hidden" title="Roofbox possible">Roofbox possible</span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-sedan hidden">Sedan</span><span class="size-f hidden">F</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">6.2 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">130 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">395 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">274 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">590 mph</span>
# <span class="fastcharge_speed hidden">590</span>
# </p>
# <span class="range hidden">395 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£105,610</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£1,589</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/2005/Peugeot-e-3008-98-kWh-Long-Range"><img alt="Peugeot e-3008 98 kWh Long Range" data-src="/img/auto/Peugeot_e-3008_2024/Peugeot_e-3008_2024-01-thumb.jpg" data-src-retina="/img/auto/Peugeot_e-3008_2024/Peugeot_e-3008_2024-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/2005/Peugeot-e-3008-98-kWh-Long-Range"><span class="peugeot">Peugeot</span> <span class="model">e-3008 98 kWh Long Range</span></a></h2><span class="date_from hidden">1706742000</span><span class="date_to hidden"></span><span class="rank hidden">276</span><span class="id hidden">2005</span> <span class="not-current">(from 2024)</span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">980</span>
#           98 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">150</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£16 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from February 2024</span>
# </div>
# </div>
# <div class="icons">
# <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="Front Wheel Drive"><span class="voor fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="voor far fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-c hidden">C</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62*</span>
# <span class="acceleration">7.0 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed*</span>
# <span class="topspeed">112 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">320 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">306 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">420 mph</span>
# <span class="fastcharge_speed hidden">420</span>
# </p>
# <span class="range hidden">320 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter40-50" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£48,000 *</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£625</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/2004/Peugeot-e-3008-73-kWh-Dual-Motor"><img alt="Peugeot e-3008 73 kWh Dual Motor" data-src="/img/auto/Peugeot_e-3008_2024/Peugeot_e-3008_2024-01-thumb.jpg" data-src-retina="/img/auto/Peugeot_e-3008_2024/Peugeot_e-3008_2024-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/2004/Peugeot-e-3008-73-kWh-Dual-Motor"><span class="peugeot">Peugeot</span> <span class="model">e-3008 73 kWh Dual Motor</span></a></h2><span class="date_from hidden">1706742000</span><span class="date_to hidden"></span><span class="rank hidden">46</span><span class="id hidden">2004</span> <span class="not-current">(from 2024)</span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">730</span>
#           73 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">183</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£15 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from February 2024</span>
# </div>
# </div>
# <div class="icons">
# <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="awd fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-c hidden">C</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62*</span>
# <span class="acceleration">6.0 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed*</span>
# <span class="topspeed">112 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">240 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">304 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">280 mph</span>
# <span class="fastcharge_speed hidden">280</span>
# </p>
# <span class="range hidden">240 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter40-50" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£44,000 *</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£575</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/2003/Peugeot-e-3008-73-kWh"><img alt="Peugeot e-3008 73 kWh" data-src="/img/auto/Peugeot_e-3008_2024/Peugeot_e-3008_2024-01-thumb.jpg" data-src-retina="/img/auto/Peugeot_e-3008_2024/Peugeot_e-3008_2024-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/2003/Peugeot-e-3008-73-kWh"><span class="peugeot">Peugeot</span> <span class="model">e-3008 73 kWh</span></a></h2><span class="date_from hidden">1706742000</span><span class="date_to hidden"></span><span class="rank hidden">110</span><span class="id hidden">2003</span> <span class="not-current">(from 2024)</span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">730</span>
#           73 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">168</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£14 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from February 2024</span>
# </div>
# </div>
# <div class="icons">
# <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="Front Wheel Drive"><span class="voor fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="voor far fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-c hidden">C</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62*</span>
# <span class="acceleration">7.0 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed*</span>
# <span class="topspeed">112 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">250 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">292 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">290 mph</span>
# <span class="fastcharge_speed hidden">290</span>
# </p>
# <span class="range hidden">250 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter40-50" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£42,000 *</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£550</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/2002/BYD-SEAL-825-kWh-AWD-Excellence"><img alt="BYD SEAL 82.5 kWh AWD Excellence" data-src="/img/auto/BYD_SEAL/BYD_SEAL-01-thumb.jpg" data-src-retina="/img/auto/BYD_SEAL/BYD_SEAL-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/2002/BYD-SEAL-825-kWh-AWD-Excellence"><span class="byd">BYD</span> <span class="model">SEAL 82.5 kWh AWD Excellence</span></a></h2><span class="date_from hidden">1693519200</span><span class="date_to hidden"></span><span class="rank hidden">152</span><span class="id hidden">2002</span><span class="current"></span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">825</span>
#           82.5 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">162</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£16 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since September 2023</span>
# </div>
# </div>
# <div class="icons">
# <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="awd fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-sedan hidden">Sedan</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">3.8 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">112 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">300 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">275 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">330 mph</span>
# <span class="fastcharge_speed hidden">330</span>
# </p>
# <span class="range hidden">300 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter40-50" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£48,695</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£750</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/2001/BYD-SEAL-825-kWh-RWD-Design"><img alt="BYD SEAL 82.5 kWh RWD Design" data-src="/img/auto/BYD_SEAL/BYD_SEAL-01-thumb.jpg" data-src-retina="/img/auto/BYD_SEAL/BYD_SEAL-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/2001/BYD-SEAL-825-kWh-RWD-Design"><span class="byd">BYD</span> <span class="model">SEAL 82.5 kWh RWD Design</span></a></h2><span class="date_from hidden">1693519200</span><span class="date_to hidden"></span><span class="rank hidden">287</span><span class="id hidden">2001</span><span class="current"></span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">825</span>
#           82.5 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">147</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£15 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since September 2023</span>
# </div>
# </div>
# <div class="icons">
# <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="Rear Wheel Drive"><span class="achter far fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="achter fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-sedan hidden">Sedan</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">5.9 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">112 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">310 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">266 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">340 mph</span>
# <span class="fastcharge_speed hidden">340</span>
# </p>
# <span class="range hidden">310 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter40-50" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£45,695</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£650</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/2000/Smart-3-Brabus"><img alt="Smart #3 Brabus" data-src="/img/auto/Smart_3_Brabus_2024/Smart_3_Brabus_2024-01-thumb.jpg" data-src-retina="/img/auto/Smart_3_Brabus_2024/Smart_3_Brabus_2024-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/2000/Smart-3-Brabus"><span class="smart">Smart</span> <span class="model">#3 Brabus</span></a></h2><span class="date_from hidden">1706742000</span><span class="date_to hidden"></span><span class="rank hidden">100</span><span class="id hidden">2000</span> <span class="not-current">(from 2024)</span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">620</span>
#           62 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">220</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£15 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from February 2024</span>
# </div>
# </div>
# <div class="icons">
# <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1600</span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="awd fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-c hidden">C</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">3.7 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">112 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">205 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">302 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">310 mph</span>
# <span class="fastcharge_speed hidden">310</span>
# </p>
# <span class="range hidden">205 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter40-50" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£45,000 *</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£600</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/1999/Smart-3"><img alt="Smart #3 " data-src="/img/auto/Smart_3_2024/Smart_3_2024-01-thumb.jpg" data-src-retina="/img/auto/Smart_3_2024/Smart_3_2024-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/1999/Smart-3"><span class="smart">Smart</span> <span class="model">#3 </span></a></h2><span class="date_from hidden">1706742000</span><span class="date_to hidden"></span><span class="rank hidden">172</span><span class="id hidden">1999</span> <span class="not-current">(from 2024)</span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">620</span>
#           62 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">168</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£12 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from February 2024</span>
# </div>
# </div>
# <div class="icons">
# <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1600</span><span title="Rear Wheel Drive"><span class="achter far fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="achter fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-c hidden">C</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">6.7 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">112 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">220 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">282 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">340 mph</span>
# <span class="fastcharge_speed hidden">340</span>
# </p>
# <span class="range hidden">220 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter30-40" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£37,000 *</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£475</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/1998/Mini-Cooper-Electric-SE"><img alt="Mini Cooper Electric SE" data-src="/img/auto/Mini_Cooper_Electric_2024/Mini_Cooper_Electric_2024-01-thumb.jpg" data-src-retina="/img/auto/Mini_Cooper_Electric_2024/Mini_Cooper_Electric_2024-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/1998/Mini-Cooper-Electric-SE"><span class="mini">Mini</span> <span class="model">Cooper Electric SE</span></a></h2><span class="date_from hidden">1698793200</span><span class="date_to hidden"></span><span class="rank hidden">96</span><span class="id hidden">1998</span> <span class="not-current">(coming soon)</span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">490</span>
#           49 kWh* |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">182</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£11 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from November 2023</span>
# </div>
# </div>
# <div class="icons">
# <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="Front Wheel Drive"><span class="voor fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="voor far fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-hatchback hidden">Hatchback</span><span class="size-b hidden">B</span><span class="seats-4 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">4</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">6.7 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">106 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">190 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# ...
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£511</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/1240/Mercedes-EQV-300"><img alt="Mercedes EQV 300" data-src="/img/auto/Mercedes_EQV/Mercedes_EQV-01-thumb.jpg" data-src-retina="/img/auto/Mercedes_EQV/Mercedes_EQV-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/1240/Mercedes-EQV-300"><span class="mercedes">Mercedes</span> <span class="model">EQV 300</span></a></h2><span class="date_from hidden">1604185200</span><span class="date_to hidden"></span><span class="rank hidden">80</span><span class="id hidden">1240</span><span class="current"></span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">900</span>
#           90 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">463</span> /mi |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£29 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since November 2020</span>
# </div>
# </div>
# <div class="icons">
# <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="Front Wheel Drive"><span class="voor fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="voor far fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-spv hidden">SPV</span><span class="size-n hidden">N</span><span class="seats-7 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">7</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">12.1 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">99 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range</span>
# <span class="erange_real">190 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency</span>
# <span class="efficiency">474 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">190 mph</span>
# <span class="fastcharge_speed hidden">190</span>
# </p>
# <span class="range hidden">190 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£87,995</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£1,017</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/1233/Honda-e-Advance"><img alt="Honda e Advance" data-src="/img/auto/Honda_e/Honda_e-01-thumb.jpg" data-src-retina="/img/auto/Honda_e/Honda_e-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/1233/Honda-e-Advance"><span class="honda">Honda</span> <span class="model">e Advance</span></a></h2><span class="date_from hidden">1598911200</span><span class="date_to hidden"></span><span class="rank hidden">72</span><span class="id hidden">1233</span><span class="current"></span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">285</span>
#           28.5 kWh* |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">356</span> /mi |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£12 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since September 2020</span>
# </div>
# </div>
# <div class="icons">
# <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="Rear Wheel Drive"><span class="achter far fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="achter fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-hatchback hidden">Hatchback</span><span class="size-b hidden">B</span><span class="seats-4 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">4</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">8.3 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">90 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range</span>
# <span class="erange_real">105 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency</span>
# <span class="efficiency">271 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">110 mph</span>
# <span class="fastcharge_speed hidden">110</span>
# </p>
# <span class="range hidden">105 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter30-40" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£37,395</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£479</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/1205/Renault-Zoe-ZE50-R135"><img alt="Renault Zoe ZE50 R135" data-src="/img/auto/Renault_Zoe_2020/Renault_Zoe_2020-01-thumb.jpg" data-src-retina="/img/auto/Renault_Zoe_2020/Renault_Zoe_2020-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/1205/Renault-Zoe-ZE50-R135"><span class="renault">Renault</span> <span class="model">Zoe ZE50 R135</span></a></h2><span class="date_from hidden">1577833200</span><span class="date_to hidden"></span><span class="rank hidden">451</span><span class="id hidden">1205</span><span class="current"></span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">520</span>
#           52 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">158</span> /mi |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£10 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since January 2020</span>
# </div>
# </div>
# <div class="icons">
# <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="Front Wheel Drive"><span class="voor fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="voor far fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-hatchback hidden">Hatchback</span><span class="size-b hidden">B</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">9.5 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">87 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range</span>
# <span class="erange_real">190 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency</span>
# <span class="efficiency">274 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">140 mph</span>
# <span class="fastcharge_speed hidden">140</span>
# </p>
# <span class="range hidden">190 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter20-30" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£29,995</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£473</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/1183/Tesla-Model-Y-Long-Range-Performance"><img alt="Tesla Model Y Long Range Performance" data-src="/img/auto/Tesla_Model_Y/Tesla_Model_Y-01-thumb.jpg" data-src-retina="/img/auto/Tesla_Model_Y/Tesla_Model_Y-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/1183/Tesla-Model-Y-Long-Range-Performance"><span class="tesla">Tesla</span> <span class="model">Model Y Long Range Performance</span></a></h2><span class="date_from hidden">1664575200</span><span class="date_to hidden"></span><span class="rank hidden">175</span><span class="id hidden">1183</span><span class="current"></span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">750</span>
#           75 kWh* |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">231</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£20 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since October 2022</span>
# </div>
# </div>
# <div class="icons">
# <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1600</span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="awd fas fa-circle"></span></span><span class="roofrack hidden" title="Roofbox possible">Roofbox possible</span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">3.7 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">155 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">260 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">288 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">400 mph</span>
# <span class="fastcharge_speed hidden">400</span>
# </p>
# <span class="range hidden">260 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter50-75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£59,990</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£749</span> pcm</span>
# </span>
# </div>
# </div>
# </div><div class="list-item">
# <div class="data-wrapper">
# <!-- img -->
# <div class="img">
# <a href="/uk/car/1153/Audi-e-tron-GT-RS"><img alt="Audi e-tron GT RS" data-src="/img/auto/Audi_e-tron_GT_RS/Audi_e-tron_GT_RS-01-thumb.jpg" data-src-retina="/img/auto/Audi_e-tron_GT_RS/Audi_e-tron_GT_RS-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
# <!-- item-data -->
# <div class="title-wrap">
# <h2><a class="title" href="/uk/car/1153/Audi-e-tron-GT-RS"><span class="audi">Audi</span> <span class="model">e-tron GT RS</span></a></h2><span class="date_from hidden">1619820000</span><span class="date_to hidden"></span><span class="rank hidden">260</span><span class="id hidden">1153</span><span class="current"></span>
# <div class="subtitle">
# <span class="BEV hidden">Battery Electric Vehicle</span>
# <span class="battery hidden">850</span>
#           85 kWh |
#           £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">476</span> /mi* |
#           <span class="bijtelling16">2% BIK</span> -
#           <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£40 pcm</span>
# <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since May 2021</span>
# </div>
# </div>
# <div class="icons">
# <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# <span class="awd fas fa-circle"></span></span><span class="roofrack hidden" title="Roofbox possible">Roofbox possible</span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-sedan hidden">Sedan</span><span class="size-f hidden">F</span><span class="seats-4 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">4</span>
# </div>
# <div class="specs">
# <p class="left">
# <span class="tag">0 - 62</span>
# <span class="acceleration">3.3 sec</span>
# </p>
# <p class="left">
# <span class="tag">Top Speed</span>
# <span class="topspeed">155 mph</span>
# </p>
# <p class="left">
# <span class="tag">Range*</span>
# <span class="erange_real">250 mi</span>
# </p>
# <p class="left">
# <span class="tag">Efficiency*</span>
# <span class="efficiency">340 Wh/mi</span>
# </p>
# <p class="left">
# <span class="tag">Rapidcharge</span>
# <span class="fastcharge_speed_print">610 mph</span>
# <span class="fastcharge_speed hidden">610</span>
# </p>
# <span class="range hidden">250 mi</span>
# </div>
# <div class="pricing align-center">
# <span class="price_buy">
# <span class="price price_filter75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£119,000</span>
# <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£1,651</span> pcm</span>
# </span>
# </div>
# </div>
# </div></div>

# %%
# Find the list item
listitem = table.find_all(class_='list-item')
listitem
# Out:
# [<div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/2033/Volkswagen-ID5-GTX"><img alt="Volkswagen ID.5 GTX" data-src="/img/auto/Volkswagen_ID5_GTX_2023/Volkswagen_ID5_GTX_2023-01-thumb.jpg" data-src-retina="/img/auto/Volkswagen_ID5_GTX_2023/Volkswagen_ID5_GTX_2023-01-thumb@2x.jpg" src="/img/auto/Volkswagen_ID5_GTX_2023/Volkswagen_ID5_GTX_2023-01-thumb@2x.jpg"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/2033/Volkswagen-ID5-GTX"><span class="volkswagen">Volkswagen</span> <span class="model">ID.5 GTX</span></a></h2><span class="date_from hidden">1698793200</span><span class="date_to hidden"></span><span class="rank hidden">11</span><span class="id hidden">2033</span> <span class="not-current">(coming soon)</span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">770</span>
#            77 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">215</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£19 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from November 2023</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1200</span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="awd fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">5.5 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">112 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">265 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">291 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">390 mph</span>
#  <span class="fastcharge_speed hidden">390</span>
#  </p>
#  <span class="range hidden">265 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter50-75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£57,000 *</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£750</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/2031/Volkswagen-ID5-Pro"><img alt="Volkswagen ID.5 Pro" data-src="/img/auto/Volkswagen_ID5/Volkswagen_ID5-01-thumb.jpg" data-src-retina="/img/auto/Volkswagen_ID5/Volkswagen_ID5-01-thumb@2x.jpg" src="/img/auto/Volkswagen_ID5/Volkswagen_ID5-01-thumb@2x.jpg"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/2031/Volkswagen-ID5-Pro"><span class="volkswagen">Volkswagen</span> <span class="model">ID.5 Pro</span></a></h2><span class="date_from hidden">1698793200</span><span class="date_to hidden"></span><span class="rank hidden">11</span><span class="id hidden">2031</span> <span class="not-current">(coming soon)</span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">770</span>
#            77 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">182</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£17 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from November 2023</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1000</span><span title="Rear Wheel Drive"><span class="achter far fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="achter fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">6.7 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">112 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">285 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">270 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">420 mph</span>
#  <span class="fastcharge_speed hidden">420</span>
#  </p>
#  <span class="range hidden">285 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter50-75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£52,000 *</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£700</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/2030/Volkswagen-ID4-GTX"><img alt="Volkswagen ID.4 GTX" data-src="/img/auto/Volkswagen_ID4_GTX_2023/Volkswagen_ID4_GTX_2023-01-thumb.jpg" data-src-retina="/img/auto/Volkswagen_ID4_GTX_2023/Volkswagen_ID4_GTX_2023-01-thumb@2x.jpg" src="/img/auto/Volkswagen_ID4_GTX_2023/Volkswagen_ID4_GTX_2023-01-thumb@2x.jpg"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/2030/Volkswagen-ID4-GTX"><span class="volkswagen">Volkswagen</span> <span class="model">ID.4 GTX</span></a></h2><span class="date_from hidden">1698793200</span><span class="date_to hidden"></span><span class="rank hidden">4</span><span class="id hidden">2030</span> <span class="not-current">(coming soon)</span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">770</span>
#            77 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">204</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£18 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from November 2023</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1200</span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="awd fas fa-circle"></span></span><span class="roofrack hidden" title="Roofbox possible">Roofbox possible</span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">5.4 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">112 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">260 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">296 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">390 mph</span>
#  <span class="fastcharge_speed hidden">390</span>
#  </p>
#  <span class="range hidden">260 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter50-75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£53,000 *</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£700</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/2028/Volkswagen-ID4-Pro"><img alt="Volkswagen ID.4 Pro" data-src="/img/auto/Volkswagen_ID4/Volkswagen_ID4-01-thumb.jpg" data-src-retina="/img/auto/Volkswagen_ID4/Volkswagen_ID4-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/2028/Volkswagen-ID4-Pro"><span class="volkswagen">Volkswagen</span> <span class="model">ID.4 Pro</span></a></h2><span class="date_from hidden">1698793200</span><span class="date_to hidden"></span><span class="rank hidden">28</span><span class="id hidden">2028</span> <span class="not-current">(coming soon)</span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">770</span>
#            77 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">167</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£15 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from November 2023</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1000</span><span title="Rear Wheel Drive"><span class="achter far fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="achter fas fa-circle"></span></span><span class="roofrack hidden" title="Roofbox possible">Roofbox possible</span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">6.7 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">112 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">270 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">285 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">400 mph</span>
#  <span class="fastcharge_speed hidden">400</span>
#  </p>
#  <span class="range hidden">270 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter40-50" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£45,000 *</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£600</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/2027/Volkswagen-ID4-Pure"><img alt="Volkswagen ID.4 Pure" data-src="/img/auto/Volkswagen_ID4/Volkswagen_ID4-01-thumb.jpg" data-src-retina="/img/auto/Volkswagen_ID4/Volkswagen_ID4-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/2027/Volkswagen-ID4-Pure"><span class="volkswagen">Volkswagen</span> <span class="model">ID.4 Pure</span></a></h2><span class="date_from hidden">1698793200</span><span class="date_to hidden"></span><span class="rank hidden">11</span><span class="id hidden">2027</span> <span class="not-current">(coming soon)</span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">520</span>
#            52 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">223</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£13 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from November 2023</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1000</span><span title="Rear Wheel Drive"><span class="achter far fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="achter fas fa-circle"></span></span><span class="roofrack hidden" title="Roofbox possible">Roofbox possible</span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">9.0 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">99 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">175 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">297 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">220 mph</span>
#  <span class="fastcharge_speed hidden">220</span>
#  </p>
#  <span class="range hidden">175 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter30-40" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£39,000 *</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£525</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/2012/Mercedes-EQS-AMG-53-4MATICplus"><img alt="Mercedes EQS AMG 53 4MATIC+" data-src="/img/auto/Mercedes_EQS_AMG_2021/Mercedes_EQS_AMG_2021-01-thumb.jpg" data-src-retina="/img/auto/Mercedes_EQS_AMG_2021/Mercedes_EQS_AMG_2021-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/2012/Mercedes-EQS-AMG-53-4MATICplus"><span class="mercedes">Mercedes</span> <span class="model">EQS AMG 53 4MATIC+</span></a></h2><span class="date_from hidden">1685570400</span><span class="date_to hidden"></span><span class="rank hidden">90</span><span class="id hidden">2012</span><span class="current"></span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">1084</span>
#            108.4 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">483</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£54 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since June 2023</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">750</span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="awd fas fa-circle"></span></span><span class="roofrack hidden" title="Roofbox possible">Roofbox possible</span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-sedan hidden">Sedan</span><span class="size-f hidden">F</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">3.4 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">155 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">335 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">324 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">500 mph</span>
#  <span class="fastcharge_speed hidden">500</span>
#  </p>
#  <span class="range hidden">335 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£161,860</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£1,696</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/2008/Mercedes-EQS-450plus"><img alt="Mercedes EQS 450+" data-src="/img/auto/Mercedes_EQS_2021/Mercedes_EQS_2021-01-thumb.jpg" data-src-retina="/img/auto/Mercedes_EQS_2021/Mercedes_EQS_2021-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/2008/Mercedes-EQS-450plus"><span class="mercedes">Mercedes</span> <span class="model">EQS 450+</span></a></h2><span class="date_from hidden">1685570400</span><span class="date_to hidden"></span><span class="rank hidden">214</span><span class="id hidden">2008</span><span class="current"></span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">1084</span>
#            108.4 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">267</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£35 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since June 2023</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">750</span><span title="Rear Wheel Drive"><span class="achter far fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="achter fas fa-circle"></span></span><span class="roofrack hidden" title="Roofbox possible">Roofbox possible</span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-sedan hidden">Sedan</span><span class="size-f hidden">F</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">6.2 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">130 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">395 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">274 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">590 mph</span>
#  <span class="fastcharge_speed hidden">590</span>
#  </p>
#  <span class="range hidden">395 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£105,610</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£1,589</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/2005/Peugeot-e-3008-98-kWh-Long-Range"><img alt="Peugeot e-3008 98 kWh Long Range" data-src="/img/auto/Peugeot_e-3008_2024/Peugeot_e-3008_2024-01-thumb.jpg" data-src-retina="/img/auto/Peugeot_e-3008_2024/Peugeot_e-3008_2024-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/2005/Peugeot-e-3008-98-kWh-Long-Range"><span class="peugeot">Peugeot</span> <span class="model">e-3008 98 kWh Long Range</span></a></h2><span class="date_from hidden">1706742000</span><span class="date_to hidden"></span><span class="rank hidden">276</span><span class="id hidden">2005</span> <span class="not-current">(from 2024)</span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">980</span>
#            98 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">150</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£16 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from February 2024</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="Front Wheel Drive"><span class="voor fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="voor far fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-c hidden">C</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62*</span>
#  <span class="acceleration">7.0 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed*</span>
#  <span class="topspeed">112 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">320 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">306 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">420 mph</span>
#  <span class="fastcharge_speed hidden">420</span>
#  </p>
#  <span class="range hidden">320 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter40-50" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£48,000 *</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£625</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/2004/Peugeot-e-3008-73-kWh-Dual-Motor"><img alt="Peugeot e-3008 73 kWh Dual Motor" data-src="/img/auto/Peugeot_e-3008_2024/Peugeot_e-3008_2024-01-thumb.jpg" data-src-retina="/img/auto/Peugeot_e-3008_2024/Peugeot_e-3008_2024-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/2004/Peugeot-e-3008-73-kWh-Dual-Motor"><span class="peugeot">Peugeot</span> <span class="model">e-3008 73 kWh Dual Motor</span></a></h2><span class="date_from hidden">1706742000</span><span class="date_to hidden"></span><span class="rank hidden">46</span><span class="id hidden">2004</span> <span class="not-current">(from 2024)</span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">730</span>
#            73 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">183</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£15 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from February 2024</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="awd fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-c hidden">C</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62*</span>
#  <span class="acceleration">6.0 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed*</span>
#  <span class="topspeed">112 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">240 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">304 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">280 mph</span>
#  <span class="fastcharge_speed hidden">280</span>
#  </p>
#  <span class="range hidden">240 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter40-50" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£44,000 *</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£575</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/2003/Peugeot-e-3008-73-kWh"><img alt="Peugeot e-3008 73 kWh" data-src="/img/auto/Peugeot_e-3008_2024/Peugeot_e-3008_2024-01-thumb.jpg" data-src-retina="/img/auto/Peugeot_e-3008_2024/Peugeot_e-3008_2024-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/2003/Peugeot-e-3008-73-kWh"><span class="peugeot">Peugeot</span> <span class="model">e-3008 73 kWh</span></a></h2><span class="date_from hidden">1706742000</span><span class="date_to hidden"></span><span class="rank hidden">110</span><span class="id hidden">2003</span> <span class="not-current">(from 2024)</span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">730</span>
#            73 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">168</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£14 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from February 2024</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="Front Wheel Drive"><span class="voor fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="voor far fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-c hidden">C</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62*</span>
#  <span class="acceleration">7.0 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed*</span>
#  <span class="topspeed">112 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">250 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">292 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">290 mph</span>
#  <span class="fastcharge_speed hidden">290</span>
#  </p>
#  <span class="range hidden">250 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter40-50" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£42,000 *</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£550</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/2002/BYD-SEAL-825-kWh-AWD-Excellence"><img alt="BYD SEAL 82.5 kWh AWD Excellence" data-src="/img/auto/BYD_SEAL/BYD_SEAL-01-thumb.jpg" data-src-retina="/img/auto/BYD_SEAL/BYD_SEAL-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/2002/BYD-SEAL-825-kWh-AWD-Excellence"><span class="byd">BYD</span> <span class="model">SEAL 82.5 kWh AWD Excellence</span></a></h2><span class="date_from hidden">1693519200</span><span class="date_to hidden"></span><span class="rank hidden">152</span><span class="id hidden">2002</span><span class="current"></span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">825</span>
#            82.5 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">162</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£16 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since September 2023</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="awd fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-sedan hidden">Sedan</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">3.8 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">112 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">300 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">275 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">330 mph</span>
#  <span class="fastcharge_speed hidden">330</span>
#  </p>
#  <span class="range hidden">300 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter40-50" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£48,695</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£750</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/2001/BYD-SEAL-825-kWh-RWD-Design"><img alt="BYD SEAL 82.5 kWh RWD Design" data-src="/img/auto/BYD_SEAL/BYD_SEAL-01-thumb.jpg" data-src-retina="/img/auto/BYD_SEAL/BYD_SEAL-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/2001/BYD-SEAL-825-kWh-RWD-Design"><span class="byd">BYD</span> <span class="model">SEAL 82.5 kWh RWD Design</span></a></h2><span class="date_from hidden">1693519200</span><span class="date_to hidden"></span><span class="rank hidden">287</span><span class="id hidden">2001</span><span class="current"></span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">825</span>
#            82.5 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">147</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£15 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since September 2023</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="Rear Wheel Drive"><span class="achter far fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="achter fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-sedan hidden">Sedan</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">5.9 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">112 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">310 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">266 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">340 mph</span>
#  <span class="fastcharge_speed hidden">340</span>
#  </p>
#  <span class="range hidden">310 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter40-50" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£45,695</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£650</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/2000/Smart-3-Brabus"><img alt="Smart #3 Brabus" data-src="/img/auto/Smart_3_Brabus_2024/Smart_3_Brabus_2024-01-thumb.jpg" data-src-retina="/img/auto/Smart_3_Brabus_2024/Smart_3_Brabus_2024-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/2000/Smart-3-Brabus"><span class="smart">Smart</span> <span class="model">#3 Brabus</span></a></h2><span class="date_from hidden">1706742000</span><span class="date_to hidden"></span><span class="rank hidden">100</span><span class="id hidden">2000</span> <span class="not-current">(from 2024)</span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">620</span>
#            62 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">220</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£15 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from February 2024</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1600</span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="awd fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-c hidden">C</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">3.7 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">112 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">205 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">302 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">310 mph</span>
#  <span class="fastcharge_speed hidden">310</span>
#  </p>
#  <span class="range hidden">205 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter40-50" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£45,000 *</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£600</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/1999/Smart-3"><img alt="Smart #3 " data-src="/img/auto/Smart_3_2024/Smart_3_2024-01-thumb.jpg" data-src-retina="/img/auto/Smart_3_2024/Smart_3_2024-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/1999/Smart-3"><span class="smart">Smart</span> <span class="model">#3 </span></a></h2><span class="date_from hidden">1706742000</span><span class="date_to hidden"></span><span class="rank hidden">172</span><span class="id hidden">1999</span> <span class="not-current">(from 2024)</span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">620</span>
#            62 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">168</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£12 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from February 2024</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1600</span><span title="Rear Wheel Drive"><span class="achter far fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="achter fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-c hidden">C</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">6.7 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">112 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">220 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">282 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">340 mph</span>
#  <span class="fastcharge_speed hidden">340</span>
#  </p>
#  <span class="range hidden">220 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter30-40" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£37,000 *</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£475</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/1998/Mini-Cooper-Electric-SE"><img alt="Mini Cooper Electric SE" data-src="/img/auto/Mini_Cooper_Electric_2024/Mini_Cooper_Electric_2024-01-thumb.jpg" data-src-retina="/img/auto/Mini_Cooper_Electric_2024/Mini_Cooper_Electric_2024-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/1998/Mini-Cooper-Electric-SE"><span class="mini">Mini</span> <span class="model">Cooper Electric SE</span></a></h2><span class="date_from hidden">1698793200</span><span class="date_to hidden"></span><span class="rank hidden">96</span><span class="id hidden">1998</span> <span class="not-current">(coming soon)</span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">490</span>
#            49 kWh* |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">182</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£11 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Expected from November 2023</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="Front Wheel Drive"><span class="voor fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
# ...
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/1240/Mercedes-EQV-300"><img alt="Mercedes EQV 300" data-src="/img/auto/Mercedes_EQV/Mercedes_EQV-01-thumb.jpg" data-src-retina="/img/auto/Mercedes_EQV/Mercedes_EQV-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/1240/Mercedes-EQV-300"><span class="mercedes">Mercedes</span> <span class="model">EQV 300</span></a></h2><span class="date_from hidden">1604185200</span><span class="date_to hidden"></span><span class="rank hidden">80</span><span class="id hidden">1240</span><span class="current"></span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">900</span>
#            90 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">463</span> /mi |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£29 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since November 2020</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="Front Wheel Drive"><span class="voor fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="voor far fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="roofrails hidden" title="Roofrails">Roofrails</span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-spv hidden">SPV</span><span class="size-n hidden">N</span><span class="seats-7 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">7</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">12.1 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">99 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range</span>
#  <span class="erange_real">190 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency</span>
#  <span class="efficiency">474 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">190 mph</span>
#  <span class="fastcharge_speed hidden">190</span>
#  </p>
#  <span class="range hidden">190 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£87,995</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£1,017</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/1233/Honda-e-Advance"><img alt="Honda e Advance" data-src="/img/auto/Honda_e/Honda_e-01-thumb.jpg" data-src-retina="/img/auto/Honda_e/Honda_e-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/1233/Honda-e-Advance"><span class="honda">Honda</span> <span class="model">e Advance</span></a></h2><span class="date_from hidden">1598911200</span><span class="date_to hidden"></span><span class="rank hidden">72</span><span class="id hidden">1233</span><span class="current"></span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">285</span>
#            28.5 kWh* |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">356</span> /mi |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£12 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since September 2020</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="Rear Wheel Drive"><span class="achter far fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="achter fas fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-hatchback hidden">Hatchback</span><span class="size-b hidden">B</span><span class="seats-4 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">4</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">8.3 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">90 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range</span>
#  <span class="erange_real">105 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency</span>
#  <span class="efficiency">271 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">110 mph</span>
#  <span class="fastcharge_speed hidden">110</span>
#  </p>
#  <span class="range hidden">105 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter30-40" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£37,395</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£479</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/1205/Renault-Zoe-ZE50-R135"><img alt="Renault Zoe ZE50 R135" data-src="/img/auto/Renault_Zoe_2020/Renault_Zoe_2020-01-thumb.jpg" data-src-retina="/img/auto/Renault_Zoe_2020/Renault_Zoe_2020-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/1205/Renault-Zoe-ZE50-R135"><span class="renault">Renault</span> <span class="model">Zoe ZE50 R135</span></a></h2><span class="date_from hidden">1577833200</span><span class="date_to hidden"></span><span class="rank hidden">451</span><span class="id hidden">1205</span><span class="current"></span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">520</span>
#            52 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">158</span> /mi |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£10 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since January 2020</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="Front Wheel Drive"><span class="voor fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="voor far fa-circle"></span></span><span class="hidden" title="Roofbox not possible"></span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-hatchback hidden">Hatchback</span><span class="size-b hidden">B</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">9.5 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">87 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range</span>
#  <span class="erange_real">190 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency</span>
#  <span class="efficiency">274 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">140 mph</span>
#  <span class="fastcharge_speed hidden">140</span>
#  </p>
#  <span class="range hidden">190 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter20-30" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£29,995</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£473</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/1183/Tesla-Model-Y-Long-Range-Performance"><img alt="Tesla Model Y Long Range Performance" data-src="/img/auto/Tesla_Model_Y/Tesla_Model_Y-01-thumb.jpg" data-src-retina="/img/auto/Tesla_Model_Y/Tesla_Model_Y-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/1183/Tesla-Model-Y-Long-Range-Performance"><span class="tesla">Tesla</span> <span class="model">Model Y Long Range Performance</span></a></h2><span class="date_from hidden">1664575200</span><span class="date_to hidden"></span><span class="rank hidden">175</span><span class="id hidden">1183</span><span class="current"></span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">750</span>
#            75 kWh* |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">231</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£20 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since October 2022</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="tow-hitch hidden">Towbar possible</span><span class="fas fa-trailer" title="Towbar possible"></span><span class="towweight" title="Towing capacity in kg">1600</span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="awd fas fa-circle"></span></span><span class="roofrack hidden" title="Roofbox possible">Roofbox possible</span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-suv hidden">SUV</span><span class="size-d hidden">D</span><span class="seats-5 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">5</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">3.7 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">155 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">260 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">288 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">400 mph</span>
#  <span class="fastcharge_speed hidden">400</span>
#  </p>
#  <span class="range hidden">260 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter50-75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£59,990</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£749</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>,
#  <div class="list-item">
#  <div class="data-wrapper">
#  <!-- img -->
#  <div class="img">
#  <a href="/uk/car/1153/Audi-e-tron-GT-RS"><img alt="Audi e-tron GT RS" data-src="/img/auto/Audi_e-tron_GT_RS/Audi_e-tron_GT_RS-01-thumb.jpg" data-src-retina="/img/auto/Audi_e-tron_GT_RS/Audi_e-tron_GT_RS-01-thumb@2x.jpg" src="/img/common/ajax-loader.gif"/></a> </div>
#  <!-- item-data -->
#  <div class="title-wrap">
#  <h2><a class="title" href="/uk/car/1153/Audi-e-tron-GT-RS"><span class="audi">Audi</span> <span class="model">e-tron GT RS</span></a></h2><span class="date_from hidden">1619820000</span><span class="date_to hidden"></span><span class="rank hidden">260</span><span class="id hidden">1153</span><span class="current"></span>
#  <div class="subtitle">
#  <span class="BEV hidden">Battery Electric Vehicle</span>
#  <span class="battery hidden">850</span>
#            85 kWh |
#            £<span class="price-range" title="Price per mile of range: indication of value for money. Combination of affordability and range. Lower figure is better.">476</span> /mi* |
#            <span class="bijtelling16">2% BIK</span> -
#            <span class="bijtelling" id="bijtelling" title="Monthly BIK at 20% Band">£40 pcm</span>
#  <span class="block" title="Date vehicle was available to order / is expected to become available to order.">Available since May 2021</span>
#  </div>
#  </div>
#  <div class="icons">
#  <span class="towweight fas fa-trailer" style="color: lightgrey;" title="Towbar not possible"></span><span title="All Wheel Drive"><span class="awd fas fa-circle" style="padding-left: 10px; margin-right: -3px;"></span>
#  <span class="awd fas fa-circle"></span></span><span class="roofrack hidden" title="Roofbox possible">Roofbox possible</span><span class="hidden" title="No Roofrails"></span><span class="3-phase hidden" title="3-Phase">3-Phase Charging</span><span class="plug-type2-ccs hidden" title="plug-type2-ccs">Type 2 CCS</span><span class="shape-sedan hidden">Sedan</span><span class="size-f hidden">F</span><span class="seats-4 fas fa-user" style="padding-left: 10px;" title="Number of seats"></span><span title="Number of seats">4</span>
#  </div>
#  <div class="specs">
#  <p class="left">
#  <span class="tag">0 - 62</span>
#  <span class="acceleration">3.3 sec</span>
#  </p>
#  <p class="left">
#  <span class="tag">Top Speed</span>
#  <span class="topspeed">155 mph</span>
#  </p>
#  <p class="left">
#  <span class="tag">Range*</span>
#  <span class="erange_real">250 mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Efficiency*</span>
#  <span class="efficiency">340 Wh/mi</span>
#  </p>
#  <p class="left">
#  <span class="tag">Rapidcharge</span>
#  <span class="fastcharge_speed_print">610 mph</span>
#  <span class="fastcharge_speed hidden">610</span>
#  </p>
#  <span class="range hidden">250 mi</span>
#  </div>
#  <div class="pricing align-center">
#  <span class="price_buy">
#  <span class="price price_filter75" title="Starting from price (OTR). Includes VAT, 1st year VED, first reg fee and delivery.">£119,000</span>
#  <span class="tag" id="lease" title="Leasing Indication (BCH) exc VAT. For comparison only, actual offers can differ significantly."><span class="lease">£1,651</span> pcm</span>
#  </span>
#  </div>
#  </div>
#  </div>]

# %%
# Store the following items: Title, PriceRange, Efficiency, RapidCharge, Range, MSRP

Title = []
PriceRange = []
Efficiency = []
Rapidcharge = []
Range = []
MSRP = []

# Loop through list items to build data for items; strip text to leave numbers as integers
for evcar in listitem:
    title = evcar.find(class_='title')
    Title.append(title.text)
    
    pricerange = evcar.find(class_='price-range')
    PriceRange.append(pricerange.text.strip("/mi"))
    
    efficiency = evcar.find(class_='efficiency')
    Efficiency.append(efficiency.text.strip("Wh/mi"))
    
    rapidcharge = evcar.find(class_="fastcharge_speed_print")
    Rapidcharge.append(rapidcharge.text.strip("mph"))
    
    range1 = evcar.find(class_='erange_real')
    Range.append(range1.text.strip("mi"))
    
    msrp = evcar.find(class_="price_buy")
    MSRP.append(msrp.text[0:9].strip("\n£").replace(",",""))

# %%
# Create dataframe for collected items from looping
df = pd.DataFrame({
    "Model": Title,
    "PriceRange": PriceRange,
    "Efficiency": Efficiency,
    "Rapidcharge": Rapidcharge,
    "Range": Range,
    "MSRP": MSRP
})
df.head(228)
# Out:
#                                     Model PriceRange Efficiency Rapidcharge  \
# 0                     Volkswagen ID.5 GTX        215       291         390
# 1                     Volkswagen ID.5 Pro        182       270         420
# 2                     Volkswagen ID.4 GTX        204       296         390
# 3                     Volkswagen ID.4 Pro        167       285         400
# 4                    Volkswagen ID.4 Pure        223       297         220
# ..                                    ...        ...        ...         ...
# 223                       BMW i4 eDrive40        181       252         490
# 224                      Mercedes EQV 300        463       474         190
# 225                       Honda e Advance        356       271         110
# 226                 Renault Zoe ZE50 R135        158       274         140
# 227  Tesla Model Y Long Range Performance        231       288         400
#
#     Range    MSRP
# 0    265   57000
# 1    285   52000
# 2    260   53000
# 3    270   45000
# 4    175   39000
# ..    ...     ...
# 223  320    57890
# 224  190    87995
# 225  105    37395
# 226  190    29995
# 227  260    59990
#
# [228 rows x 6 columns]

# %%
# Replace all datatypes as integers for ease of data base creation
df = df.astype({"PriceRange": int, "Efficiency": int, "Rapidcharge": int, "Range": int, "MSRP": int})

# %%
# Double check integer types
df.dtypes
# Out:
# Model          object
# PriceRange      int32
# Efficiency      int32
# Rapidcharge     int32
# Range           int32
# MSRP            int32
# dtype: object

# %%
# Export CSV file 
df.to_csv('EV_Analysis_Database.csv', index=True)

# %%
browser.quit()
